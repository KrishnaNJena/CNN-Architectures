# %%
# !nvidia-smi
# Out:
# Sat Apr 10 08:52:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/CNN/AlexNet'
# Out:
# /content/drive/MyDrive/CNN/AlexNet

# %%
# !pip install tflearn
# Out:
# Requirement already satisfied: tflearn in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tflearn) (1.19.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tflearn) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tflearn) (1.15.0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Activation,Dropout
from keras.layers.normalization import BatchNormalization
import numpy as np
import tflearn.datasets.oxflower17 as oxflower17
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
x,y=oxflower17.load_data(one_hot=True)
print(x.shape,y.shape)
# Out:
# (1360, 224, 224, 3) (1360, 17)

# %%
#Create a sequential model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11),\
 strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Pooling 
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(17))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 54, 54, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 54, 54, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 17, 17, 256)       2973952
# _________________________________________________________________
# activation_1 (Activation)    (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 384)         1536
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_7 (Activation)    (None, 1000)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1000)              4000
# _________________________________________________________________
# dense_3 (Dense)              (None, 17)                17017
# _________________________________________________________________
# activation_8 (Activation)    (None, 17)                0
# =================================================================
# Total params: 28,096,769
# Trainable params: 28,075,633
# Non-trainable params: 21,136
# _________________________________________________________________

# %%
# Compile 
model.compile(loss='categorical_crossentropy', optimizer='adam',\
 metrics=['accuracy'])
model.fit(x, y, batch_size=100, epochs=50, verbose=1,validation_split=0.2, shuffle=True)
# Out:
# Train on 1088 samples, validate on 272 samples
# Epoch 1/50
# 1088/1088 [==============================] - ETA: 0s - loss: 3.0528 - acc: 0.2151
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1088/1088 [==============================] - 10s 9ms/sample - loss: 3.0528 - acc: 0.2151 - val_loss: 16.1304 - val_acc: 0.0846
# Epoch 2/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 2.2090 - acc: 0.3658 - val_loss: 50.2690 - val_acc: 0.0919
# Epoch 3/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.7852 - acc: 0.4596 - val_loss: 29.0420 - val_acc: 0.1250
# Epoch 4/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.5077 - acc: 0.5129 - val_loss: 18.9244 - val_acc: 0.1176
# Epoch 5/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.2976 - acc: 0.5726 - val_loss: 10.8145 - val_acc: 0.1581
# Epoch 6/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.2280 - acc: 0.5993 - val_loss: 3.7607 - val_acc: 0.2794
# Epoch 7/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.2379 - acc: 0.5928 - val_loss: 4.0936 - val_acc: 0.2721
# Epoch 8/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 1.0316 - acc: 0.6535 - val_loss: 3.0304 - val_acc: 0.3125
# Epoch 9/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.8514 - acc: 0.7022 - val_loss: 3.1797 - val_acc: 0.2941
# Epoch 10/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.7540 - acc: 0.7399 - val_loss: 2.1133 - val_acc: 0.3824
# Epoch 11/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.6925 - acc: 0.7610 - val_loss: 2.2016 - val_acc: 0.4044
# Epoch 12/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.6580 - acc: 0.7785 - val_loss: 2.1764 - val_acc: 0.4081
# Epoch 13/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.5446 - acc: 0.8162 - val_loss: 3.9778 - val_acc: 0.3272
# Epoch 14/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.5232 - acc: 0.8125 - val_loss: 2.6001 - val_acc: 0.4007
# Epoch 15/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.4691 - acc: 0.8520 - val_loss: 2.3690 - val_acc: 0.4154
# Epoch 16/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.5489 - acc: 0.8189 - val_loss: 2.7107 - val_acc: 0.3934
# Epoch 17/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3773 - acc: 0.8722 - val_loss: 2.7833 - val_acc: 0.4375
# Epoch 18/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3432 - acc: 0.8888 - val_loss: 3.3005 - val_acc: 0.4375
# Epoch 19/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3228 - acc: 0.8934 - val_loss: 4.3943 - val_acc: 0.3272
# Epoch 20/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.2893 - acc: 0.9026 - val_loss: 2.8511 - val_acc: 0.4559
# Epoch 21/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3654 - acc: 0.8759 - val_loss: 3.2010 - val_acc: 0.4632
# Epoch 22/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3430 - acc: 0.8860 - val_loss: 3.9221 - val_acc: 0.4706
# Epoch 23/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3406 - acc: 0.8915 - val_loss: 3.8845 - val_acc: 0.4632
# Epoch 24/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.3168 - acc: 0.8915 - val_loss: 2.6827 - val_acc: 0.5037
# Epoch 25/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.2192 - acc: 0.9265 - val_loss: 4.2705 - val_acc: 0.4191
# Epoch 26/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1938 - acc: 0.9393 - val_loss: 2.9685 - val_acc: 0.5074
# Epoch 27/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1823 - acc: 0.9439 - val_loss: 4.1008 - val_acc: 0.4449
# Epoch 28/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1649 - acc: 0.9412 - val_loss: 2.9815 - val_acc: 0.5331
# Epoch 29/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1350 - acc: 0.9513 - val_loss: 2.7023 - val_acc: 0.5404
# Epoch 30/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1000 - acc: 0.9669 - val_loss: 4.6223 - val_acc: 0.4596
# Epoch 31/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1158 - acc: 0.9697 - val_loss: 2.8112 - val_acc: 0.5662
# Epoch 32/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0837 - acc: 0.9715 - val_loss: 2.4799 - val_acc: 0.6140
# Epoch 33/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0763 - acc: 0.9743 - val_loss: 2.8342 - val_acc: 0.5478
# Epoch 34/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0657 - acc: 0.9807 - val_loss: 2.7581 - val_acc: 0.5772
# Epoch 35/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0517 - acc: 0.9825 - val_loss: 2.8392 - val_acc: 0.5588
# Epoch 36/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0655 - acc: 0.9779 - val_loss: 2.9627 - val_acc: 0.5551
# Epoch 37/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1341 - acc: 0.9632 - val_loss: 3.9503 - val_acc: 0.5110
# Epoch 38/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1315 - acc: 0.9586 - val_loss: 2.8843 - val_acc: 0.5625
# Epoch 39/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1310 - acc: 0.9568 - val_loss: 2.8849 - val_acc: 0.5184
# Epoch 40/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1155 - acc: 0.9577 - val_loss: 3.0347 - val_acc: 0.5331
# Epoch 41/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1396 - acc: 0.9568 - val_loss: 2.5109 - val_acc: 0.6066
# Epoch 42/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0803 - acc: 0.9752 - val_loss: 2.9090 - val_acc: 0.5662
# Epoch 43/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0474 - acc: 0.9816 - val_loss: 2.9473 - val_acc: 0.5662
# Epoch 44/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0439 - acc: 0.9844 - val_loss: 3.0602 - val_acc: 0.5551
# Epoch 45/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1150 - acc: 0.9688 - val_loss: 2.3738 - val_acc: 0.6324
# Epoch 46/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1067 - acc: 0.9642 - val_loss: 3.5154 - val_acc: 0.5588
# Epoch 47/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.1122 - acc: 0.9660 - val_loss: 3.0509 - val_acc: 0.5588
# Epoch 48/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0721 - acc: 0.9715 - val_loss: 3.8280 - val_acc: 0.5294
# Epoch 49/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0643 - acc: 0.9789 - val_loss: 3.1800 - val_acc: 0.5368
# Epoch 50/50
# 1088/1088 [==============================] - 1s 1ms/sample - loss: 0.0699 - acc: 0.9761 - val_loss: 3.7365 - val_acc: 0.5588
